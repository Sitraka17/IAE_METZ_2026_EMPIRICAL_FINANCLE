# %% [markdown]
# # Premiers exercices

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule de code 
#Python est une Porgrammation orienté OBKJET. On déf des variables
name = "Ajla"
print(name)
# Out:
# Ajla

# %%
# sinon j'appelle la variable
name
# Out:
# 'Ajla'

# %%
name = "Thomas"
name
# la dernière def de variable l'emporte
# Out:
# 'Thomas'

# %%
# Pour les chiffres on a 
age = 26 # INTEGER donc les nombres entiers 
print(age)
# Out:
# 26

# %%
pi = 3.14159
pi
# Out:
# 3.14159

# %%
# un dictionnaire c est CLE VALEUR 

prices = {
    "APPL":248.04,
    "GOOGLE":328.33,
    "TSLA":437.43
}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}
